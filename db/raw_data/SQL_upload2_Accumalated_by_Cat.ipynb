# %%
import pandas as pd
from sqlalchemy import create_engine
import json

# %%
US_file = "USvideos.csv"
US_df = pd.read_csv(US_file, encoding="ISO-8859-1") 
US_df = pd.DataFrame(US_df)
US_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
GB_file = "GBvideos.csv"
GB_df = pd.read_csv(GB_file, encoding="ISO-8859-1") 
GB_df.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1        Taylor Swift: â¦Ready for It? (Live) - SNL
# 2        Eminem - Walk On Water (Audio) ft. BeyoncÃ©
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
numb = []
cat = []
with open('US_category_id.json') as json_file:
    data = json.load(json_file)
    for x in data['items']:
        numb.append(x['id'])
        cat.append(x['snippet']['title'])
    df = {
        'category_id': numb,
        'category': cat
    }
    US_cat = pd.DataFrame(df)
US_cat.head()
# Out:
#   category_id          category
# 0           1  Film & Animation
# 1           2  Autos & Vehicles
# 2          10             Music
# 3          15    Pets & Animals
# 4          17            Sports

# %%
US_cat['category_id'] = US_cat['category_id'].astype('int64')
US_df = US_df.merge(US_cat)
US_df = US_df[['video_id', 'trending_date', 'title', 'channel_title', 'category_id', 'category',
       'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
       'thumbnail_link', 'comments_disabled', 'ratings_disabled',
       'video_error_or_removed', 'description']]
US_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  0mlNzVSJrT0      17.14.11
# 2  STI2fI7sKMo      17.14.11
# 3  KODzih-pYlU      17.14.11
# 4  8mhTWqWlQzU      17.14.11
#
#                                                title       channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                               Me-O Cats Commercial             Nobrand
# 2  AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3  BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4      Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
#
#    category_id        category              publish_time  \
# 0           22  People & Blogs  2017-11-13T17:13:01.000Z
# 1           22  People & Blogs  2017-04-21T06:47:32.000Z
# 2           22  People & Blogs  2017-11-11T15:00:03.000Z
# 3           22  People & Blogs  2017-11-11T18:08:04.000Z
# ...

# %%
numb = []
cat = []
with open('GB_category_id.json') as json_file:
    data = json.load(json_file)
    for x in data['items']:
        numb.append(x['id'])
        cat.append(x['snippet']['title'])
    df = {
        'category_id': numb,
        'category': cat
    }
    GB_cat = pd.DataFrame(df)
GB_cat.head()
# Out:
#   category_id          category
# 0           1  Film & Animation
# 1           2  Autos & Vehicles
# 2          10             Music
# 3          15    Pets & Animals
# 4          17            Sports

# %%
GB_cat['category_id'] = GB_cat['category_id'].astype('int64')
GB_df = GB_df.merge(GB_cat)
GB_df = GB_df[['video_id', 'trending_date', 'title', 'channel_title', 'category_id', 'category',
       'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
       'thumbnail_link', 'comments_disabled', 'ratings_disabled',
       'video_error_or_removed', 'description']]
GB_df.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  MyEqfBkzESU      17.14.11
# 2  b4vTZx_AtHk      17.14.11
# 3  OWvCCu2t6Ts      17.14.11
# 4  9GqL1DSQDL0      17.14.11
#
#                                                title         channel_title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster            John Lewis
# 1                  EXTREME GOLDEN TAN TRANSFORMATION          John Maclean
# 2                   How To Dry a Shirt in 30 Seconds            HowToBasic
# 3  SO Much To Tell You | 32 Weeks Pregnant | MOTH...     Sprinkleofglitter
# 4  GET READY WITH ME + LILY! (we're so immature bye)  makeupbymichaelfinch
#
#    category_id       category              publish_time  \
# 0           26  Howto & Style  2017-11-10T07:38:29.000Z
# 1           26  Howto & Style  2017-11-10T20:40:44.000Z
# 2           26  Howto & Style  2017-11-09T18:36:48.000Z
# 3           26  Howto & Style  2017-11-10T16:59:50.000Z
# ...

# %%
# File to Load (Remember to Change These)
file1 = "USvideos_catID.csv"
file2 = "GBvideos_catID.csv"

# Read Purchasing File and store into Pandas data frame
USvideos_sumBy_catID_df = pd.read_csv(file1)
GBvideos_sumBy_catID_df = pd.read_csv(file2)

# %%
USvideos_sumBy_catID_df
# Out:
#     category_id       views      likes  dislikes  comment_count  \
# 0             1   825269649   17039389    690859        1971012
# 1             2   102913586     730306     46397         123347
# 2            10  4828186880  150641535   5264500       12865083
# 3            15   104204643    2670772     67898         359305
# 4            17   639466822   12586093    797203        1490099
# 5            19    58778988     586846     39306         105656
# 6            20   239483937    6991366    624992        1386717
# 7            22   667660862   23000159   1377442        3052960
# 8            23   773873112   29957127   1067459        2986431
# 9            24  2828466347   67435226   6730460        9899089
# 10           25   231807005    3011179    769826        1078391
# 11           26   557056875   20646383    705227        2894411
# 12           27   152579019    5402061    189946         634097
# 13           28   428563438   10165574    547825        1391101
# ...

# %%
USsum_withCat_df = USvideos_sumBy_catID_df.merge(US_cat)

# %%
USsum_withCat_df = USsum_withCat_df.drop(['comment_count', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'], axis=1)

# %%
USsum_withCat_df
# Out:
#     category_id       views      likes  dislikes               category
# 0             1   825269649   17039389    690859       Film & Animation
# 1             2   102913586     730306     46397       Autos & Vehicles
# 2            10  4828186880  150641535   5264500                  Music
# 3            15   104204643    2670772     67898         Pets & Animals
# 4            17   639466822   12586093    797203                 Sports
# 5            19    58778988     586846     39306        Travel & Events
# 6            20   239483937    6991366    624992                 Gaming
# 7            22   667660862   23000159   1377442         People & Blogs
# 8            23   773873112   29957127   1067459                 Comedy
# 9            24  2828466347   67435226   6730460          Entertainment
# 10           25   231807005    3011179    769826        News & Politics
# 11           26   557056875   20646383    705227          Howto & Style
# ...

# %%
GBsum_withCat_df = GBvideos_sumBy_catID_df.merge(GB_cat)

# %%
GBsum_withCat_df = GBsum_withCat_df.drop(['comment_count', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'], axis=1)

# %%
GBsum_withCat_df
# Out:
#     category_id        views      likes  dislikes              category
# 0             1    488191152    7985655    424742      Film & Animation
# 1             2     20406847     349318     24374      Autos & Vehicles
# 2            10  11503508478  222846587   9311590                 Music
# 3            15     36918849     926734     22345        Pets & Animals
# 4            17    226954817    3679664    382370                Sports
# 5            19     10717623      97076      3843       Travel & Events
# 6            20    142281935    4392270    175406                Gaming
# 7            22    356606299    9372266    791587        People & Blogs
# 8            23    392685843   12473617    447318                Comedy
# 9            24   2239143169   54024370   6678002         Entertainment
# 10           25     98727625    1969002    263861       News & Politics
# 11           26     89539350    3634412    121268         Howto & Style
# ...

# %%
rds_connection_string = "postgres:JusticeLeague1981!@localhost:5432/YouTube"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['USdata', 'INdata', 'USdata_sumCat', 'INdata_sumCat']

# %%
US_df.to_sql(name='USdata', con=engine, if_exists='append', index=False)
GB_df.to_sql(name='INdata', con=engine, if_exists='append', index=False)

# %%
USsum_withCat_df.to_sql(name='USdata_sumCat', con=engine, if_exists='append', index=False)
GBsum_withCat_df.to_sql(name='INdata_sumCat', con=engine, if_exists='append', index=False)
